# %% [markdown]
# # Feature Pyramid Networks (FPN)

# %% [markdown]
# ## Functional API

# %%
import tensorflow as tf


def conv_norm(
    x: tf.Tensor,
    filters: int,
    ksize: int,
    *,
    downsample: bool = False,
    act: bool = True,
):
    """Conv2D + BatchNorm with optional ReLU activation.

    Args:
        x (tf.Tensor): Input tensor.
        filters (int): Number of output channels.
        ksize (int): Kernel size. If 1 (i.e. projection shortcut), use valid
            padding; otherwise, use same padding.
        downsample (bool): down-sampling flag i.e. set stride to 2 if
            downsample add stride 1 otherwise.
            Always do the 0 padding i.e. padding = 'same'
        act (bool): ReLU activation flag.

    Returns:
        tf.Tensor: Output tensor after the Conv2D and BatchNormalization
            operations.
    """
    strides = 2 if downsample else 1

    if ksize == 1:
        padding = "valid"
    else:
        padding = "same"

    x = tf.keras.layers.Conv2D(
        filters=filters,
        kernel_size=ksize,
        strides=strides,
        use_bias=False,
        padding=padding,
    )(x)

    x = tf.keras.layers.BatchNormalization()(x)

    if act:
        x = tf.nn.relu(x)
    return x


def bottleneck(
    x: tf.Tensor,
    filters: int,
    *,
    ds: bool = False,
    lead: bool = False,
):
    """A bottleneck residual block using the functional API.

    It consists of 3 Conv2D layers with kernel size 1, 3, 1 respectively.
    Compared to the basic residual block, it has an 1x1 projection shortcuts,
    which is used to reduce the channel dimensionality to save computation.

    Args:
        x (tf.Tensor): Input tensor.
        filters (int): Number of output channels.
        ds (bool, optional): Down-sampling flag. Defaults to False.
        lead (bool, optional): Lead flag to determine if it's the first block.
            Defaults to False.

    Returns:
        tf.Tensor: Output tensor after applying the BottleNeck operations.
    """
    # expanded output channels
    outs = filters * 4

    if lead:
        identity = conv_norm(x, outs, ksize=1, downsample=ds, act=False)
    else:
        identity = x

    x = conv_norm(x, filters, ksize=1, downsample=False, act=True)
    x = conv_norm(x, filters, ksize=3, downsample=ds, act=True)
    x = conv_norm(x, outs, ksize=1, downsample=False, act=False)
    return tf.nn.relu(identity + x)


def res_stack(
    x: tf.Tensor,
    filter: int,
    num: int,
    *,
    ds: bool = False,
) -> tf.keras.Sequential:
    """A stack of bottleneck residual blocks.

    Args:
        x (tf.Tensor): Input tensor.
        filter (int): number of output channels
        num (int): number of bottleneck blocks
        ds (bool): down-sampling flag.

    Returns:
        tf.keras.Sequential: a stack of bottleneck blocks
    """
    x = bottleneck(x, filter, ds=ds, lead=True)
    for _ in range(1, num):
        x = bottleneck(x, filter, ds=False, lead=False)

    return x


def topdown_stack(c: tf.Tensor, p: tf.Tensor) -> tf.Tensor:
    """A top-down stack of feature maps.

    1. the bottom-up feature map `c` is reduced to 256 channels using a 1x1
       Conv2D layer.
    2. the top-down feature map `p` is upsampled to the same size as `c` by
       resizing.
    3. the two feature maps are added together.
    4. the combined feature map is smoothed using a 3x3 Conv2D layer.

    Args:
        c (tf.Tensor): Input tensor from bottom-up pathway.
        p (tf.Tensor): Input tensor from top-down pathway.

    Returns:
        tf.Tensor: Output tensor after the top-down stack.
    """
    # reduce channels
    c = conv_norm(c, 256, ksize=1, downsample=False, act=True)
    _, H, W, _ = c.shape
    p = tf.image.resize(p, (H, W)) + c
    # smooth
    p = conv_norm(p, 256, ksize=3, downsample=False, act=True)
    return p


def fpn(input_shape):
    """Constructs the Feature Pyramid Network (FPN) model.

    Args:
        input_shape (tuple): Shape of the input tensor.
        num_classes (int): Number of classification classes.

    Returns:
        tf.keras.Model: The DeepResNet model.
    """

    inputs = tf.keras.layers.Input(shape=input_shape)  # (B, H, W, C)

    # Initial layers
    # shape: (B, H/2, W/2, 64)
    x = conv_norm(inputs, 64, ksize=7, downsample=True, act=True)
    # shape: (B, H/4, W/4, 64)
    x = tf.nn.max_pool2d(x, ksize=3, strides=2, padding="SAME")

    # bottom-up pathway
    c2 = res_stack(x, 64, 3, ds=False)  # (B, H/4, W/4, 256)
    c3 = res_stack(c2, 128, 4, ds=True)  # (B, H/8, W/8, 512)
    c4 = res_stack(c3, 256, 6, ds=True)  # (B, H/16, W/16, 1024)
    c5 = res_stack(c4, 512, 3, ds=True)  # (B, H/32, W/32, 2048)

    # top-down pathway
    # shape: (B, H/32, W/32, 256)
    p5 = conv_norm(c5, 256, ksize=1, downsample=False, act=True)
    p4 = topdown_stack(c4, p5)  # (B, H/16, W/16, 256)
    p3 = topdown_stack(c3, p4)  # (B, H/8, W/8, 256)
    p2 = topdown_stack(c2, p3)  # (B, H/4, W/4, 256)

    return tf.keras.Model(inputs=inputs, outputs=[p2, p3, p4, p5])

# %%
in_shape = (416, 416, 3)
batch = 2
x = tf.random.normal(shape=(batch, *in_shape))
model = fpn(in_shape)
model.summary()
y2, y3, y4, y5 = model(x, training=False)
assert y2.shape == (batch, 104, 104, 256)
assert y3.shape == (batch, 52, 52, 256)
assert y4.shape == (batch, 26, 26, 256)
assert y5.shape == (batch, 13, 13, 256)
# Out:
# 2023-09-23 01:54:12.229754: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 416, 416, 3)]        0         []
#
#  conv2d (Conv2D)             (None, 208, 208, 64)         9408      ['input_1[0][0]']
#
#  batch_normalization (Batch  (None, 208, 208, 64)         256       ['conv2d[0][0]']
#  Normalization)
#
#  tf.nn.relu (TFOpLambda)     (None, 208, 208, 64)         0         ['batch_normalization[0][0]']
#
#  tf.nn.max_pool2d (TFOpLamb  (None, 104, 104, 64)         0         ['tf.nn.relu[0][0]']
#  da)
#
#  conv2d_2 (Conv2D)           (None, 104, 104, 64)         4096      ['tf.nn.max_pool2d[0][0]']
#
#  batch_normalization_2 (Bat  (None, 104, 104, 64)         256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 104, 104, 64)         0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 104, 104, 64)         36864     ['tf.nn.relu_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 104, 104, 64)         256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 104, 104, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  conv2d_1 (Conv2D)           (None, 104, 104, 256)        16384     ['tf.nn.max_pool2d[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 104, 104, 256)        16384     ['tf.nn.relu_2[0][0]']
#
#  batch_normalization_1 (Bat  (None, 104, 104, 256)        1024      ['conv2d_1[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 104, 104, 256)        1024      ['conv2d_4[0][0]']
#  chNormalization)
#
#  tf.__operators__.add (TFOp  (None, 104, 104, 256)        0         ['batch_normalization_1[0][0]'
#  Lambda)                                                            , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 104, 104, 256)        0         ['tf.__operators__.add[0][0]']
#
#  conv2d_5 (Conv2D)           (None, 104, 104, 64)         16384     ['tf.nn.relu_3[0][0]']
#
#  batch_normalization_5 (Bat  (None, 104, 104, 64)         256       ['conv2d_5[0][0]']
#  chNormalization)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 104, 104, 64)         0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  conv2d_6 (Conv2D)           (None, 104, 104, 64)         36864     ['tf.nn.relu_4[0][0]']
#
#  batch_normalization_6 (Bat  (None, 104, 104, 64)         256       ['conv2d_6[0][0]']
#  chNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 104, 104, 64)         0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 104, 104, 256)        16384     ['tf.nn.relu_5[0][0]']
#
#  batch_normalization_7 (Bat  (None, 104, 104, 256)        1024      ['conv2d_7[0][0]']
#  chNormalization)
#
#  tf.__operators__.add_1 (TF  (None, 104, 104, 256)        0         ['tf.nn.relu_3[0][0]',
#  OpLambda)                                                           'batch_normalization_7[0][0]'
#                                                                     ]
#
#  tf.nn.relu_6 (TFOpLambda)   (None, 104, 104, 256)        0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  conv2d_8 (Conv2D)           (None, 104, 104, 64)         16384     ['tf.nn.relu_6[0][0]']
#
#  batch_normalization_8 (Bat  (None, 104, 104, 64)         256       ['conv2d_8[0][0]']
#  chNormalization)
#
#  tf.nn.relu_7 (TFOpLambda)   (None, 104, 104, 64)         0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 104, 104, 64)         36864     ['tf.nn.relu_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 104, 104, 64)         256       ['conv2d_9[0][0]']
#  chNormalization)
#
#  tf.nn.relu_8 (TFOpLambda)   (None, 104, 104, 64)         0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_10 (Conv2D)          (None, 104, 104, 256)        16384     ['tf.nn.relu_8[0][0]']
#
#  batch_normalization_10 (Ba  (None, 104, 104, 256)        1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_2 (TF  (None, 104, 104, 256)        0         ['tf.nn.relu_6[0][0]',
#  OpLambda)                                                           'batch_normalization_10[0][0]
#                                                                     ']
#
#  tf.nn.relu_9 (TFOpLambda)   (None, 104, 104, 256)        0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  conv2d_12 (Conv2D)          (None, 104, 104, 128)        32768     ['tf.nn.relu_9[0][0]']
#
#  batch_normalization_12 (Ba  (None, 104, 104, 128)        512       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_10 (TFOpLambda)  (None, 104, 104, 128)        0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_13 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.nn.relu_10[0][0]']
#
#  batch_normalization_13 (Ba  (None, 52, 52, 128)          512       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_11 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  conv2d_11 (Conv2D)          (None, 52, 52, 512)          131072    ['tf.nn.relu_9[0][0]']
#
#  conv2d_14 (Conv2D)          (None, 52, 52, 512)          65536     ['tf.nn.relu_11[0][0]']
#
#  batch_normalization_11 (Ba  (None, 52, 52, 512)          2048      ['conv2d_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 52, 52, 512)          2048      ['conv2d_14[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_3 (TF  (None, 52, 52, 512)          0         ['batch_normalization_11[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ']
#
#  tf.nn.relu_12 (TFOpLambda)  (None, 52, 52, 512)          0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  conv2d_15 (Conv2D)          (None, 52, 52, 128)          65536     ['tf.nn.relu_12[0][0]']
#
#  batch_normalization_15 (Ba  (None, 52, 52, 128)          512       ['conv2d_15[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_13 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_15[0][0]
#                                                                     ']
#
#  conv2d_16 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.nn.relu_13[0][0]']
#
#  batch_normalization_16 (Ba  (None, 52, 52, 128)          512       ['conv2d_16[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_14 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ']
#
#  conv2d_17 (Conv2D)          (None, 52, 52, 512)          65536     ['tf.nn.relu_14[0][0]']
#
#  batch_normalization_17 (Ba  (None, 52, 52, 512)          2048      ['conv2d_17[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_4 (TF  (None, 52, 52, 512)          0         ['tf.nn.relu_12[0][0]',
#  OpLambda)                                                           'batch_normalization_17[0][0]
#                                                                     ']
#
#  tf.nn.relu_15 (TFOpLambda)  (None, 52, 52, 512)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  conv2d_18 (Conv2D)          (None, 52, 52, 128)          65536     ['tf.nn.relu_15[0][0]']
#
#  batch_normalization_18 (Ba  (None, 52, 52, 128)          512       ['conv2d_18[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_16 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_18[0][0]
#                                                                     ']
#
#  conv2d_19 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.nn.relu_16[0][0]']
#
#  batch_normalization_19 (Ba  (None, 52, 52, 128)          512       ['conv2d_19[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_17 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_19[0][0]
#                                                                     ']
#
#  conv2d_20 (Conv2D)          (None, 52, 52, 512)          65536     ['tf.nn.relu_17[0][0]']
#
#  batch_normalization_20 (Ba  (None, 52, 52, 512)          2048      ['conv2d_20[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_5 (TF  (None, 52, 52, 512)          0         ['tf.nn.relu_15[0][0]',
#  OpLambda)                                                           'batch_normalization_20[0][0]
#                                                                     ']
#
#  tf.nn.relu_18 (TFOpLambda)  (None, 52, 52, 512)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  conv2d_21 (Conv2D)          (None, 52, 52, 128)          65536     ['tf.nn.relu_18[0][0]']
#
#  batch_normalization_21 (Ba  (None, 52, 52, 128)          512       ['conv2d_21[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_19 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_21[0][0]
#                                                                     ']
#
#  conv2d_22 (Conv2D)          (None, 52, 52, 128)          147456    ['tf.nn.relu_19[0][0]']
#
#  batch_normalization_22 (Ba  (None, 52, 52, 128)          512       ['conv2d_22[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_20 (TFOpLambda)  (None, 52, 52, 128)          0         ['batch_normalization_22[0][0]
#                                                                     ']
#
#  conv2d_23 (Conv2D)          (None, 52, 52, 512)          65536     ['tf.nn.relu_20[0][0]']
#
#  batch_normalization_23 (Ba  (None, 52, 52, 512)          2048      ['conv2d_23[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_6 (TF  (None, 52, 52, 512)          0         ['tf.nn.relu_18[0][0]',
#  OpLambda)                                                           'batch_normalization_23[0][0]
#                                                                     ']
#
#  tf.nn.relu_21 (TFOpLambda)  (None, 52, 52, 512)          0         ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 52, 52, 256)          131072    ['tf.nn.relu_21[0][0]']
#
#  batch_normalization_25 (Ba  (None, 52, 52, 256)          1024      ['conv2d_25[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_22 (TFOpLambda)  (None, 52, 52, 256)          0         ['batch_normalization_25[0][0]
#                                                                     ']
#
#  conv2d_26 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.nn.relu_22[0][0]']
#
#  batch_normalization_26 (Ba  (None, 26, 26, 256)          1024      ['conv2d_26[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_23 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ']
#
#  conv2d_24 (Conv2D)          (None, 26, 26, 1024)         524288    ['tf.nn.relu_21[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 26, 26, 1024)         262144    ['tf.nn.relu_23[0][0]']
#
#  batch_normalization_24 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_24[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_27[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_7 (TF  (None, 26, 26, 1024)         0         ['batch_normalization_24[0][0]
#  OpLambda)                                                          ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ']
#
#  tf.nn.relu_24 (TFOpLambda)  (None, 26, 26, 1024)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  conv2d_28 (Conv2D)          (None, 26, 26, 256)          262144    ['tf.nn.relu_24[0][0]']
#
#  batch_normalization_28 (Ba  (None, 26, 26, 256)          1024      ['conv2d_28[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_25 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_28[0][0]
#                                                                     ']
#
#  conv2d_29 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.nn.relu_25[0][0]']
#
#  batch_normalization_29 (Ba  (None, 26, 26, 256)          1024      ['conv2d_29[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_26 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ']
#
#  conv2d_30 (Conv2D)          (None, 26, 26, 1024)         262144    ['tf.nn.relu_26[0][0]']
#
#  batch_normalization_30 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_30[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_8 (TF  (None, 26, 26, 1024)         0         ['tf.nn.relu_24[0][0]',
#  OpLambda)                                                           'batch_normalization_30[0][0]
#                                                                     ']
#
#  tf.nn.relu_27 (TFOpLambda)  (None, 26, 26, 1024)         0         ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  conv2d_31 (Conv2D)          (None, 26, 26, 256)          262144    ['tf.nn.relu_27[0][0]']
#
#  batch_normalization_31 (Ba  (None, 26, 26, 256)          1024      ['conv2d_31[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_28 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_31[0][0]
#                                                                     ']
#
#  conv2d_32 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.nn.relu_28[0][0]']
#
#  batch_normalization_32 (Ba  (None, 26, 26, 256)          1024      ['conv2d_32[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_29 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_32[0][0]
#                                                                     ']
#
#  conv2d_33 (Conv2D)          (None, 26, 26, 1024)         262144    ['tf.nn.relu_29[0][0]']
#
#  batch_normalization_33 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_33[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_9 (TF  (None, 26, 26, 1024)         0         ['tf.nn.relu_27[0][0]',
#  OpLambda)                                                           'batch_normalization_33[0][0]
#                                                                     ']
#
#  tf.nn.relu_30 (TFOpLambda)  (None, 26, 26, 1024)         0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  conv2d_34 (Conv2D)          (None, 26, 26, 256)          262144    ['tf.nn.relu_30[0][0]']
#
#  batch_normalization_34 (Ba  (None, 26, 26, 256)          1024      ['conv2d_34[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_31 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_34[0][0]
#                                                                     ']
#
#  conv2d_35 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.nn.relu_31[0][0]']
#
#  batch_normalization_35 (Ba  (None, 26, 26, 256)          1024      ['conv2d_35[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_32 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ']
#
#  conv2d_36 (Conv2D)          (None, 26, 26, 1024)         262144    ['tf.nn.relu_32[0][0]']
#
#  batch_normalization_36 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_36[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_10 (T  (None, 26, 26, 1024)         0         ['tf.nn.relu_30[0][0]',
#  FOpLambda)                                                          'batch_normalization_36[0][0]
#                                                                     ']
#
#  tf.nn.relu_33 (TFOpLambda)  (None, 26, 26, 1024)         0         ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  conv2d_37 (Conv2D)          (None, 26, 26, 256)          262144    ['tf.nn.relu_33[0][0]']
#
#  batch_normalization_37 (Ba  (None, 26, 26, 256)          1024      ['conv2d_37[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_34 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  conv2d_38 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.nn.relu_34[0][0]']
#
#  batch_normalization_38 (Ba  (None, 26, 26, 256)          1024      ['conv2d_38[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_35 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_38[0][0]
#                                                                     ']
#
#  conv2d_39 (Conv2D)          (None, 26, 26, 1024)         262144    ['tf.nn.relu_35[0][0]']
#
#  batch_normalization_39 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_39[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_11 (T  (None, 26, 26, 1024)         0         ['tf.nn.relu_33[0][0]',
#  FOpLambda)                                                          'batch_normalization_39[0][0]
#                                                                     ']
#
#  tf.nn.relu_36 (TFOpLambda)  (None, 26, 26, 1024)         0         ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  conv2d_40 (Conv2D)          (None, 26, 26, 256)          262144    ['tf.nn.relu_36[0][0]']
#
#  batch_normalization_40 (Ba  (None, 26, 26, 256)          1024      ['conv2d_40[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_37 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_40[0][0]
#                                                                     ']
#
#  conv2d_41 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.nn.relu_37[0][0]']
#
#  batch_normalization_41 (Ba  (None, 26, 26, 256)          1024      ['conv2d_41[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_38 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_41[0][0]
#                                                                     ']
#
#  conv2d_42 (Conv2D)          (None, 26, 26, 1024)         262144    ['tf.nn.relu_38[0][0]']
#
#  batch_normalization_42 (Ba  (None, 26, 26, 1024)         4096      ['conv2d_42[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_12 (T  (None, 26, 26, 1024)         0         ['tf.nn.relu_36[0][0]',
#  FOpLambda)                                                          'batch_normalization_42[0][0]
#                                                                     ']
#
#  tf.nn.relu_39 (TFOpLambda)  (None, 26, 26, 1024)         0         ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  conv2d_44 (Conv2D)          (None, 26, 26, 512)          524288    ['tf.nn.relu_39[0][0]']
#
#  batch_normalization_44 (Ba  (None, 26, 26, 512)          2048      ['conv2d_44[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_40 (TFOpLambda)  (None, 26, 26, 512)          0         ['batch_normalization_44[0][0]
#                                                                     ']
#
#  conv2d_45 (Conv2D)          (None, 13, 13, 512)          2359296   ['tf.nn.relu_40[0][0]']
#
#  batch_normalization_45 (Ba  (None, 13, 13, 512)          2048      ['conv2d_45[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_41 (TFOpLambda)  (None, 13, 13, 512)          0         ['batch_normalization_45[0][0]
#                                                                     ']
#
#  conv2d_43 (Conv2D)          (None, 13, 13, 2048)         2097152   ['tf.nn.relu_39[0][0]']
#
#  conv2d_46 (Conv2D)          (None, 13, 13, 2048)         1048576   ['tf.nn.relu_41[0][0]']
#
#  batch_normalization_43 (Ba  (None, 13, 13, 2048)         8192      ['conv2d_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_46 (Ba  (None, 13, 13, 2048)         8192      ['conv2d_46[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_13 (T  (None, 13, 13, 2048)         0         ['batch_normalization_43[0][0]
#  FOpLambda)                                                         ',
#                                                                      'batch_normalization_46[0][0]
#                                                                     ']
#
#  tf.nn.relu_42 (TFOpLambda)  (None, 13, 13, 2048)         0         ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  conv2d_47 (Conv2D)          (None, 13, 13, 512)          1048576   ['tf.nn.relu_42[0][0]']
#
#  batch_normalization_47 (Ba  (None, 13, 13, 512)          2048      ['conv2d_47[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_43 (TFOpLambda)  (None, 13, 13, 512)          0         ['batch_normalization_47[0][0]
#                                                                     ']
#
#  conv2d_48 (Conv2D)          (None, 13, 13, 512)          2359296   ['tf.nn.relu_43[0][0]']
#
#  batch_normalization_48 (Ba  (None, 13, 13, 512)          2048      ['conv2d_48[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_44 (TFOpLambda)  (None, 13, 13, 512)          0         ['batch_normalization_48[0][0]
#                                                                     ']
#
#  conv2d_49 (Conv2D)          (None, 13, 13, 2048)         1048576   ['tf.nn.relu_44[0][0]']
#
#  batch_normalization_49 (Ba  (None, 13, 13, 2048)         8192      ['conv2d_49[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_14 (T  (None, 13, 13, 2048)         0         ['tf.nn.relu_42[0][0]',
#  FOpLambda)                                                          'batch_normalization_49[0][0]
#                                                                     ']
#
#  tf.nn.relu_45 (TFOpLambda)  (None, 13, 13, 2048)         0         ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  conv2d_50 (Conv2D)          (None, 13, 13, 512)          1048576   ['tf.nn.relu_45[0][0]']
#
#  batch_normalization_50 (Ba  (None, 13, 13, 512)          2048      ['conv2d_50[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_46 (TFOpLambda)  (None, 13, 13, 512)          0         ['batch_normalization_50[0][0]
#                                                                     ']
#
#  conv2d_51 (Conv2D)          (None, 13, 13, 512)          2359296   ['tf.nn.relu_46[0][0]']
#
#  batch_normalization_51 (Ba  (None, 13, 13, 512)          2048      ['conv2d_51[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_47 (TFOpLambda)  (None, 13, 13, 512)          0         ['batch_normalization_51[0][0]
#                                                                     ']
#
#  conv2d_52 (Conv2D)          (None, 13, 13, 2048)         1048576   ['tf.nn.relu_47[0][0]']
#
#  batch_normalization_52 (Ba  (None, 13, 13, 2048)         8192      ['conv2d_52[0][0]']
#  tchNormalization)
#
#  tf.__operators__.add_15 (T  (None, 13, 13, 2048)         0         ['tf.nn.relu_45[0][0]',
#  FOpLambda)                                                          'batch_normalization_52[0][0]
#                                                                     ']
#
#  tf.nn.relu_48 (TFOpLambda)  (None, 13, 13, 2048)         0         ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  conv2d_53 (Conv2D)          (None, 13, 13, 256)          524288    ['tf.nn.relu_48[0][0]']
#
#  batch_normalization_53 (Ba  (None, 13, 13, 256)          1024      ['conv2d_53[0][0]']
#  tchNormalization)
#
#  conv2d_54 (Conv2D)          (None, 26, 26, 256)          262144    ['tf.nn.relu_39[0][0]']
#
#  tf.nn.relu_49 (TFOpLambda)  (None, 13, 13, 256)          0         ['batch_normalization_53[0][0]
#                                                                     ']
#
#  batch_normalization_54 (Ba  (None, 26, 26, 256)          1024      ['conv2d_54[0][0]']
#  tchNormalization)
#
#  tf.image.resize (TFOpLambd  (None, 26, 26, 256)          0         ['tf.nn.relu_49[0][0]']
#  a)
#
#  tf.nn.relu_50 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_54[0][0]
#                                                                     ']
#
#  tf.__operators__.add_16 (T  (None, 26, 26, 256)          0         ['tf.image.resize[0][0]',
#  FOpLambda)                                                          'tf.nn.relu_50[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 26, 26, 256)          589824    ['tf.__operators__.add_16[0][0
#                                                                     ]']
#
#  batch_normalization_55 (Ba  (None, 26, 26, 256)          1024      ['conv2d_55[0][0]']
#  tchNormalization)
#
#  conv2d_56 (Conv2D)          (None, 52, 52, 256)          131072    ['tf.nn.relu_21[0][0]']
#
#  tf.nn.relu_51 (TFOpLambda)  (None, 26, 26, 256)          0         ['batch_normalization_55[0][0]
#                                                                     ']
#
#  batch_normalization_56 (Ba  (None, 52, 52, 256)          1024      ['conv2d_56[0][0]']
#  tchNormalization)
#
#  tf.image.resize_1 (TFOpLam  (None, 52, 52, 256)          0         ['tf.nn.relu_51[0][0]']
#  bda)
#
#  tf.nn.relu_52 (TFOpLambda)  (None, 52, 52, 256)          0         ['batch_normalization_56[0][0]
#                                                                     ']
#
#  tf.__operators__.add_17 (T  (None, 52, 52, 256)          0         ['tf.image.resize_1[0][0]',
#  FOpLambda)                                                          'tf.nn.relu_52[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 52, 52, 256)          589824    ['tf.__operators__.add_17[0][0
#                                                                     ]']
#
#  batch_normalization_57 (Ba  (None, 52, 52, 256)          1024      ['conv2d_57[0][0]']
#  tchNormalization)
#
#  conv2d_58 (Conv2D)          (None, 104, 104, 256)        65536     ['tf.nn.relu_9[0][0]']
#
#  tf.nn.relu_53 (TFOpLambda)  (None, 52, 52, 256)          0         ['batch_normalization_57[0][0]
#                                                                     ']
#
#  batch_normalization_58 (Ba  (None, 104, 104, 256)        1024      ['conv2d_58[0][0]']
#  tchNormalization)
#
#  tf.image.resize_2 (TFOpLam  (None, 104, 104, 256)        0         ['tf.nn.relu_53[0][0]']
#  bda)
#
#  tf.nn.relu_54 (TFOpLambda)  (None, 104, 104, 256)        0         ['batch_normalization_58[0][0]
#                                                                     ']
#
#  tf.__operators__.add_18 (T  (None, 104, 104, 256)        0         ['tf.image.resize_2[0][0]',
#  FOpLambda)                                                          'tf.nn.relu_54[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 104, 104, 256)        589824    ['tf.__operators__.add_18[0][0
#                                                                     ]']
#
#  batch_normalization_59 (Ba  (None, 104, 104, 256)        1024      ['conv2d_59[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_55 (TFOpLambda)  (None, 104, 104, 256)        0         ['batch_normalization_59[0][0]
#                                                                     ']
#
# ==================================================================================================
# Total params: 26320832 (100.41 MB)
# Trainable params: 26264128 (100.19 MB)
# Non-trainable params: 56704 (221.50 KB)
# __________________________________________________________________________________________________
