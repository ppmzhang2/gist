# %% [markdown]
# # ResNet

# %% [markdown]
# ## Sequential API

# %% [markdown]
# ### Basic Convolution Unit

# %%
import tensorflow as tf


class ConvBlock(tf.keras.layers.Layer):
    """A Conv2D + BatchNorm block with optional down-sampling."""

    def __init__(
        self,
        filters: int,
        *,
        shortcut: bool = False,
        downsample: bool = False,
    ):
        super(ConvBlock, self).__init__()
        self.filters = filters
        self.downsample = downsample
        """Initialize the ConvBlock.

        Args:
            filters (int): number of output channels
            shortcut (bool): projection shortcut flag i.e. match the number of
                filters (done by 1x1 convolutions) if True; otherwise, match
                the number of filters and the spatial dimensions by 3x3
                convolutions with same padding.
            downsample (bool): down-sampling flag i.e. set stride to 2 if
                downsample add stride 1 otherwise.
                Always do the 0 padding i.e. padding = 'same'
        """
        # if downsample, add stride without padding,
        # otherwise stride 1 with zero padding i.e. keep the spatial dimensions
        strides = 2 if downsample else 1
        if shortcut:
            # match the number of filters (done by 1x1 convolutions)
            kernel_size = 1
            padding = "valid"
        else:
            # match the number of filters and the spatial dimensions
            # by 3x3 convolutions with same padding
            kernel_size = 3
            padding = "same"

        self._model = tf.keras.Sequential()
        self._model.add(
            tf.keras.layers.Conv2D(
                filters=filters,
                kernel_size=kernel_size,
                strides=strides,
                use_bias=False,
                padding=padding,
            ))
        self._model.add(tf.keras.layers.BatchNormalization())

    def call(self, x: tf.Tensor, *, training: bool = False) -> tf.Tensor:
        """Forward pass of the ConvBlock.

        Args:
            x (tf.Tensor): input tensor
            training (bool): training flag i.e. batch norm uses different
                behaviour for training and inference

        Returns:
            tf.Tensor: output tensor
        """
        return self._model(x, training=training)

# %%
N, H, W, C = 2, 56, 56, 64
x = tf.random.normal((N, H, W, C))
# 3x3 convolutions without down-sampling
m1 = ConvBlock(C, shortcut=False, downsample=False)
# 1x1 convolutions without down-sampling
m2 = ConvBlock(C, shortcut=True, downsample=False)
# 3x3 convolutions with down-sampling
m3 = ConvBlock(C, shortcut=False, downsample=True)
# 1x1 convolutions with down-sampling
m4 = ConvBlock(C, shortcut=True, downsample=True)

assert m1(x, training=True).shape == (N, H, W, C)
assert m2(x, training=True).shape == (N, H, W, C)
assert m3(x, training=True).shape == (N, H // 2, W // 2, C)
assert m4(x, training=True).shape == (N, H // 2, W // 2, C)
# Out:
# 2023-08-18 00:33:05.082041: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1

# %% [markdown]
# ### Bottle Neck Block

# %%
class BottleNeck(tf.keras.layers.Layer):
    """A BottleNeck of ResNet framework."""

    def __init__(self, filters: int, *, ds: bool = False, lead: bool = False):
        """Initialize the BottleNeck.

        Args:
            filters (int): number of output channels
            ds (bool): down-sampling flag.
            lead (bool): leading block flag.
        """
        super(BottleNeck, self).__init__()
        # expanded output channels
        outs = filters * 4
        # projection shortcut
        if lead:
            self._shortcut = ConvBlock(outs, shortcut=True, downsample=ds)
        else:
            self._shortcut = None
        # a stack of 1x1, 3x3, 1x1 convolutional layers
        self._body = tf.keras.Sequential()
        self._body.add(ConvBlock(filters, shortcut=True, downsample=False))
        self._body.add(tf.keras.layers.ReLU())
        self._body.add(ConvBlock(filters, shortcut=False, downsample=ds))
        self._body.add(tf.keras.layers.ReLU())
        self._body.add(ConvBlock(outs, shortcut=True, downsample=False))

    def call(self, x: tf.Tensor, *, training: bool = False) -> tf.Tensor:
        """Forward pass of the BottleNeck.

        Args:
            x (tf.Tensor): input tensor
            training (bool): training flag for BN and Dropout

        Returns:
            tf.Tensor: output tensor
        """
        # shortcut branch
        if self._shortcut is None:
            identity = x
        else:
            identity = self._shortcut(x, training=training)
        # residual branch
        residual = self._body(x, training=training)
        # add shortcut and residual before activation
        return tf.nn.relu(identity + residual)

# %%
# Conv2_x
N1, H1, W1, C1 = 2, 56, 56, 64
N2, H2, W2, C2 = 2, 56, 56, 256
N3, H3, W3, C3 = 2, 28, 28, 512
N4, H4, W4, C4 = 2, 14, 14, 1024
N5, H5, W5, C5 = 2, 7, 7, 2048
y1 = tf.random.normal((N1, H1, W1, C1))

# conv2_x
y2 = BottleNeck(C1, ds=False, lead=True)(y1)
y2 = BottleNeck(C1, ds=False)(y2)
y2 = BottleNeck(C1, ds=False)(y2)
assert y2.shape == (N2, H2, W2, C2)

# conv3_x
y3 = BottleNeck(C2 // 2, ds=True, lead=True)(y2)
y3 = BottleNeck(C2 // 2, ds=False)(y3)
y3 = BottleNeck(C2 // 2, ds=False)(y3)
assert y3.shape == (N3, H3, W3, C3)

# conv4_x
y4 = BottleNeck(C3 // 2, ds=True, lead=True)(y3)
y4 = BottleNeck(C3 // 2, ds=False)(y4)
y4 = BottleNeck(C3 // 2, ds=False)(y4)
assert y4.shape == (N4, H4, W4, C4)

# conv5_x
y5 = BottleNeck(C4 // 2, ds=True, lead=True)(y4)
y5 = BottleNeck(C4 // 2, ds=False)(y5)
y5 = BottleNeck(C4 // 2, ds=False)(y5)
assert y5.shape == (N5, H5, W5, C5)

# %% [markdown]
# ### ResNet-50

# %%
def bottleneck_stack(
    filter: int,
    num: int,
    *,
    ds: bool = False,
) -> tf.keras.Sequential:
    """A stack of BottleNeck blocks.

    Args:
        filter (int): number of output channels
        num (int): number of BottleNeck blocks
        ds (bool): down-sampling flag.

    Returns:
        tf.keras.Sequential: a stack of BottleNeck blocks
    """
    stack = tf.keras.Sequential()
    stack.add(BottleNeck(filter, ds=ds, lead=True))

    for _ in range(1, num):
        stack.add(BottleNeck(filter, ds=False, lead=False))

    return stack


class DeepResNet(tf.keras.Model):
    """Bottleneck style ResNet."""

    def __init__(self, num_classes: int):
        super(DeepResNet, self).__init__()
        self._model = tf.keras.Sequential()
        self._model.add(
            tf.keras.layers.Conv2D(
                filters=64,
                kernel_size=7,
                strides=2,
                padding="same",
                use_bias=False,
            ))
        self._model.add(tf.keras.layers.BatchNormalization())
        self._model.add(tf.keras.layers.ReLU())
        self._model.add(
            tf.keras.layers.MaxPool2D(
                pool_size=3,
                strides=2,
                padding="same",
            ))
        self._model.add(bottleneck_stack(64, 3, ds=False))
        self._model.add(bottleneck_stack(128, 4, ds=True))
        self._model.add(bottleneck_stack(256, 6, ds=True))
        self._model.add(bottleneck_stack(512, 3, ds=True))
        self._model.add(tf.keras.layers.GlobalAvgPool2D())
        self._model.add(tf.keras.layers.Dense(num_classes))

    def call(self, x: tf.Tensor, *, training: bool = False) -> tf.Tensor:
        return self._model(x, training=training)

# %%
in_shape = (224, 224, 3)
x = tf.random.normal(shape=(2, *in_shape))
model = DeepResNet(num_classes=1000)
y = model(x, training=False)
assert y.shape == (2, 1000)
model.summary()
# Out:
# Model: "deep_res_net"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_56 (Sequential)  (2, 1000)                 25610152
#
# =================================================================
# Total params: 25610152 (97.69 MB)
# Trainable params: 25557032 (97.49 MB)
# Non-trainable params: 53120 (207.50 KB)
# _________________________________________________________________

# %% [markdown]
# ## Functional API

# %%
import tensorflow as tf


def conv_norm(
    x: tf.Tensor,
    filters: int,
    kernel: int,
    *,
    downsample: bool = False,
    act: bool = True,
):
    """
    Conv2D + BatchNorm with optional ReLU activation.

    Args:
        x (tf.Tensor): Input tensor.
        filters (int): Number of output channels.
        kernel (int): Kernel size. If 1 (i.e. projection shortcut), use valid
            padding; otherwise, use same padding.
        downsample (bool): down-sampling flag i.e. set stride to 2 if
            downsample add stride 1 otherwise.
            Always do the 0 padding i.e. padding = 'same'
        act (bool): ReLU activation flag.

    Returns:
        tf.Tensor: Output tensor after the Conv2D and BatchNormalization
            operations.
    """
    strides = 2 if downsample else 1

    if kernel == 1:
        padding = "valid"
    else:
        padding = "same"

    x = tf.keras.layers.Conv2D(filters=filters,
                               kernel_size=kernel,
                               strides=strides,
                               use_bias=False,
                               padding=padding)(x)

    x = tf.keras.layers.BatchNormalization()(x)

    if act:
        x = tf.nn.relu(x)
    return x


def bottleneck(
    x: tf.Tensor,
    filters: int,
    *,
    ds: bool = False,
    lead: bool = False,
):
    """A BottleNeck block using the functional API.

    Args:
        x (tf.Tensor): Input tensor.
        filters (int): Number of output channels.
        ds (bool, optional): Down-sampling flag. Defaults to False.
        lead (bool, optional): Lead flag to determine if it's the first block.
            Defaults to False.

    Returns:
        tf.Tensor: Output tensor after applying the BottleNeck operations.
    """
    # expanded output channels
    outs = filters * 4

    if lead:
        identity = conv_norm(x, outs, kernel=1, downsample=ds, act=False)
    else:
        identity = x

    x = conv_norm(x, filters, kernel=1, downsample=False, act=True)
    x = conv_norm(x, filters, kernel=3, downsample=ds, act=True)
    x = conv_norm(x, outs, kernel=1, downsample=False, act=False)
    return tf.nn.relu(identity + x)


def bottleneck_stack(
    x: tf.Tensor,
    filter: int,
    num: int,
    *,
    ds: bool = False,
) -> tf.keras.Sequential:
    """A stack of BottleNeck blocks.

    Args:
        x (tf.Tensor): Input tensor.
        filter (int): number of output channels
        num (int): number of BottleNeck blocks
        ds (bool): down-sampling flag.

    Returns:
        tf.keras.Sequential: a stack of BottleNeck blocks
    """
    x = bottleneck(x, filter, ds=ds, lead=True)
    for _ in range(1, num):
        x = bottleneck(x, filter, ds=False, lead=False)

    return x


def deep_resnet(input_shape, num_classes):
    """
    Constructs the DeepResNet model using the functional API.

    Args:
        input_shape (tuple): Shape of the input tensor.
        num_classes (int): Number of classification classes.

    Returns:
        tf.keras.Model: The DeepResNet model.
    """

    inputs = tf.keras.layers.Input(shape=input_shape)

    # Initial layers
    x = conv_norm(inputs, 64, kernel=7, downsample=True, act=True)
    x = tf.keras.layers.MaxPool2D(pool_size=3, strides=2, padding="same")(x)

    # BottleNeck stacks
    x = bottleneck_stack(x, 64, 3, ds=False)
    x = bottleneck_stack(x, 128, 4, ds=True)
    x = bottleneck_stack(x, 256, 6, ds=True)
    x = bottleneck_stack(x, 512, 3, ds=True)

    # Final layers
    x = tf.keras.layers.GlobalAvgPool2D()(x)
    outputs = tf.keras.layers.Dense(num_classes)(x)

    return tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
in_shape = (224, 224, 3)
x = tf.random.normal(shape=(2, *in_shape))
model = deep_resnet(in_shape, 1000)
model.summary()
y = model(x, training=False)
assert y.shape == (2, 1000)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv2d_97 (Conv2D)          (None, 112, 112, 64)         9408      ['input_1[0][0]']
#
#  batch_normalization_97 (Ba  (None, 112, 112, 64)         256       ['conv2d_97[0][0]']
#  tchNormalization)
#
#  tf.nn.relu (TFOpLambda)     (None, 112, 112, 64)         0         ['batch_normalization_97[0][0]
#                                                                     ']
#
#  max_pooling2d_1 (MaxPoolin  (None, 56, 56, 64)           0         ['tf.nn.relu[0][0]']
#  g2D)
#
#  conv2d_99 (Conv2D)          (None, 56, 56, 64)           4096      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_99 (Ba  (None, 56, 56, 64)           256       ['conv2d_99[0][0]']
#  tchNormalization)
#
#  tf.nn.relu_1 (TFOpLambda)   (None, 56, 56, 64)           0         ['batch_normalization_99[0][0]
#                                                                     ']
#
#  conv2d_100 (Conv2D)         (None, 56, 56, 64)           36864     ['tf.nn.relu_1[0][0]']
#
#  batch_normalization_100 (B  (None, 56, 56, 64)           256       ['conv2d_100[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_2 (TFOpLambda)   (None, 56, 56, 64)           0         ['batch_normalization_100[0][0
#                                                                     ]']
#
#  conv2d_98 (Conv2D)          (None, 56, 56, 256)          16384     ['max_pooling2d_1[0][0]']
#
#  conv2d_101 (Conv2D)         (None, 56, 56, 256)          16384     ['tf.nn.relu_2[0][0]']
#
#  batch_normalization_98 (Ba  (None, 56, 56, 256)          1024      ['conv2d_98[0][0]']
#  tchNormalization)
#
#  batch_normalization_101 (B  (None, 56, 56, 256)          1024      ['conv2d_101[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add (TFOp  (None, 56, 56, 256)          0         ['batch_normalization_98[0][0]
#  Lambda)                                                            ',
#                                                                      'batch_normalization_101[0][0
#                                                                     ]']
#
#  tf.nn.relu_3 (TFOpLambda)   (None, 56, 56, 256)          0         ['tf.__operators__.add[0][0]']
#
#  conv2d_102 (Conv2D)         (None, 56, 56, 64)           16384     ['tf.nn.relu_3[0][0]']
#
#  batch_normalization_102 (B  (None, 56, 56, 64)           256       ['conv2d_102[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_4 (TFOpLambda)   (None, 56, 56, 64)           0         ['batch_normalization_102[0][0
#                                                                     ]']
#
#  conv2d_103 (Conv2D)         (None, 56, 56, 64)           36864     ['tf.nn.relu_4[0][0]']
#
#  batch_normalization_103 (B  (None, 56, 56, 64)           256       ['conv2d_103[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_5 (TFOpLambda)   (None, 56, 56, 64)           0         ['batch_normalization_103[0][0
#                                                                     ]']
#
#  conv2d_104 (Conv2D)         (None, 56, 56, 256)          16384     ['tf.nn.relu_5[0][0]']
#
#  batch_normalization_104 (B  (None, 56, 56, 256)          1024      ['conv2d_104[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_1 (TF  (None, 56, 56, 256)          0         ['tf.nn.relu_3[0][0]',
#  OpLambda)                                                           'batch_normalization_104[0][0
#                                                                     ]']
#
#  tf.nn.relu_6 (TFOpLambda)   (None, 56, 56, 256)          0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  conv2d_105 (Conv2D)         (None, 56, 56, 64)           16384     ['tf.nn.relu_6[0][0]']
#
#  batch_normalization_105 (B  (None, 56, 56, 64)           256       ['conv2d_105[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_7 (TFOpLambda)   (None, 56, 56, 64)           0         ['batch_normalization_105[0][0
#                                                                     ]']
#
#  conv2d_106 (Conv2D)         (None, 56, 56, 64)           36864     ['tf.nn.relu_7[0][0]']
#
#  batch_normalization_106 (B  (None, 56, 56, 64)           256       ['conv2d_106[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_8 (TFOpLambda)   (None, 56, 56, 64)           0         ['batch_normalization_106[0][0
#                                                                     ]']
#
#  conv2d_107 (Conv2D)         (None, 56, 56, 256)          16384     ['tf.nn.relu_8[0][0]']
#
#  batch_normalization_107 (B  (None, 56, 56, 256)          1024      ['conv2d_107[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_2 (TF  (None, 56, 56, 256)          0         ['tf.nn.relu_6[0][0]',
#  OpLambda)                                                           'batch_normalization_107[0][0
#                                                                     ]']
#
#  tf.nn.relu_9 (TFOpLambda)   (None, 56, 56, 256)          0         ['tf.__operators__.add_2[0][0]
#                                                                     ']
#
#  conv2d_109 (Conv2D)         (None, 56, 56, 128)          32768     ['tf.nn.relu_9[0][0]']
#
#  batch_normalization_109 (B  (None, 56, 56, 128)          512       ['conv2d_109[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_10 (TFOpLambda)  (None, 56, 56, 128)          0         ['batch_normalization_109[0][0
#                                                                     ]']
#
#  conv2d_110 (Conv2D)         (None, 28, 28, 128)          147456    ['tf.nn.relu_10[0][0]']
#
#  batch_normalization_110 (B  (None, 28, 28, 128)          512       ['conv2d_110[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_11 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_110[0][0
#                                                                     ]']
#
#  conv2d_108 (Conv2D)         (None, 28, 28, 512)          131072    ['tf.nn.relu_9[0][0]']
#
#  conv2d_111 (Conv2D)         (None, 28, 28, 512)          65536     ['tf.nn.relu_11[0][0]']
#
#  batch_normalization_108 (B  (None, 28, 28, 512)          2048      ['conv2d_108[0][0]']
#  atchNormalization)
#
#  batch_normalization_111 (B  (None, 28, 28, 512)          2048      ['conv2d_111[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_3 (TF  (None, 28, 28, 512)          0         ['batch_normalization_108[0][0
#  OpLambda)                                                          ]',
#                                                                      'batch_normalization_111[0][0
#                                                                     ]']
#
#  tf.nn.relu_12 (TFOpLambda)  (None, 28, 28, 512)          0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  conv2d_112 (Conv2D)         (None, 28, 28, 128)          65536     ['tf.nn.relu_12[0][0]']
#
#  batch_normalization_112 (B  (None, 28, 28, 128)          512       ['conv2d_112[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_13 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_112[0][0
#                                                                     ]']
#
#  conv2d_113 (Conv2D)         (None, 28, 28, 128)          147456    ['tf.nn.relu_13[0][0]']
#
#  batch_normalization_113 (B  (None, 28, 28, 128)          512       ['conv2d_113[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_14 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_113[0][0
#                                                                     ]']
#
#  conv2d_114 (Conv2D)         (None, 28, 28, 512)          65536     ['tf.nn.relu_14[0][0]']
#
#  batch_normalization_114 (B  (None, 28, 28, 512)          2048      ['conv2d_114[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_4 (TF  (None, 28, 28, 512)          0         ['tf.nn.relu_12[0][0]',
#  OpLambda)                                                           'batch_normalization_114[0][0
#                                                                     ]']
#
#  tf.nn.relu_15 (TFOpLambda)  (None, 28, 28, 512)          0         ['tf.__operators__.add_4[0][0]
#                                                                     ']
#
#  conv2d_115 (Conv2D)         (None, 28, 28, 128)          65536     ['tf.nn.relu_15[0][0]']
#
#  batch_normalization_115 (B  (None, 28, 28, 128)          512       ['conv2d_115[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_16 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_115[0][0
#                                                                     ]']
#
#  conv2d_116 (Conv2D)         (None, 28, 28, 128)          147456    ['tf.nn.relu_16[0][0]']
#
#  batch_normalization_116 (B  (None, 28, 28, 128)          512       ['conv2d_116[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_17 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_116[0][0
#                                                                     ]']
#
#  conv2d_117 (Conv2D)         (None, 28, 28, 512)          65536     ['tf.nn.relu_17[0][0]']
#
#  batch_normalization_117 (B  (None, 28, 28, 512)          2048      ['conv2d_117[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_5 (TF  (None, 28, 28, 512)          0         ['tf.nn.relu_15[0][0]',
#  OpLambda)                                                           'batch_normalization_117[0][0
#                                                                     ]']
#
#  tf.nn.relu_18 (TFOpLambda)  (None, 28, 28, 512)          0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  conv2d_118 (Conv2D)         (None, 28, 28, 128)          65536     ['tf.nn.relu_18[0][0]']
#
#  batch_normalization_118 (B  (None, 28, 28, 128)          512       ['conv2d_118[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_19 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_118[0][0
#                                                                     ]']
#
#  conv2d_119 (Conv2D)         (None, 28, 28, 128)          147456    ['tf.nn.relu_19[0][0]']
#
#  batch_normalization_119 (B  (None, 28, 28, 128)          512       ['conv2d_119[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_20 (TFOpLambda)  (None, 28, 28, 128)          0         ['batch_normalization_119[0][0
#                                                                     ]']
#
#  conv2d_120 (Conv2D)         (None, 28, 28, 512)          65536     ['tf.nn.relu_20[0][0]']
#
#  batch_normalization_120 (B  (None, 28, 28, 512)          2048      ['conv2d_120[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_6 (TF  (None, 28, 28, 512)          0         ['tf.nn.relu_18[0][0]',
#  OpLambda)                                                           'batch_normalization_120[0][0
#                                                                     ]']
#
#  tf.nn.relu_21 (TFOpLambda)  (None, 28, 28, 512)          0         ['tf.__operators__.add_6[0][0]
#                                                                     ']
#
#  conv2d_122 (Conv2D)         (None, 28, 28, 256)          131072    ['tf.nn.relu_21[0][0]']
#
#  batch_normalization_122 (B  (None, 28, 28, 256)          1024      ['conv2d_122[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_22 (TFOpLambda)  (None, 28, 28, 256)          0         ['batch_normalization_122[0][0
#                                                                     ]']
#
#  conv2d_123 (Conv2D)         (None, 14, 14, 256)          589824    ['tf.nn.relu_22[0][0]']
#
#  batch_normalization_123 (B  (None, 14, 14, 256)          1024      ['conv2d_123[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_23 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_123[0][0
#                                                                     ]']
#
#  conv2d_121 (Conv2D)         (None, 14, 14, 1024)         524288    ['tf.nn.relu_21[0][0]']
#
#  conv2d_124 (Conv2D)         (None, 14, 14, 1024)         262144    ['tf.nn.relu_23[0][0]']
#
#  batch_normalization_121 (B  (None, 14, 14, 1024)         4096      ['conv2d_121[0][0]']
#  atchNormalization)
#
#  batch_normalization_124 (B  (None, 14, 14, 1024)         4096      ['conv2d_124[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_7 (TF  (None, 14, 14, 1024)         0         ['batch_normalization_121[0][0
#  OpLambda)                                                          ]',
#                                                                      'batch_normalization_124[0][0
#                                                                     ]']
#
#  tf.nn.relu_24 (TFOpLambda)  (None, 14, 14, 1024)         0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  conv2d_125 (Conv2D)         (None, 14, 14, 256)          262144    ['tf.nn.relu_24[0][0]']
#
#  batch_normalization_125 (B  (None, 14, 14, 256)          1024      ['conv2d_125[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_25 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_125[0][0
#                                                                     ]']
#
#  conv2d_126 (Conv2D)         (None, 14, 14, 256)          589824    ['tf.nn.relu_25[0][0]']
#
#  batch_normalization_126 (B  (None, 14, 14, 256)          1024      ['conv2d_126[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_26 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_126[0][0
#                                                                     ]']
#
#  conv2d_127 (Conv2D)         (None, 14, 14, 1024)         262144    ['tf.nn.relu_26[0][0]']
#
#  batch_normalization_127 (B  (None, 14, 14, 1024)         4096      ['conv2d_127[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_8 (TF  (None, 14, 14, 1024)         0         ['tf.nn.relu_24[0][0]',
#  OpLambda)                                                           'batch_normalization_127[0][0
#                                                                     ]']
#
#  tf.nn.relu_27 (TFOpLambda)  (None, 14, 14, 1024)         0         ['tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  conv2d_128 (Conv2D)         (None, 14, 14, 256)          262144    ['tf.nn.relu_27[0][0]']
#
#  batch_normalization_128 (B  (None, 14, 14, 256)          1024      ['conv2d_128[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_28 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 14, 14, 256)          589824    ['tf.nn.relu_28[0][0]']
#
#  batch_normalization_129 (B  (None, 14, 14, 256)          1024      ['conv2d_129[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_29 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  conv2d_130 (Conv2D)         (None, 14, 14, 1024)         262144    ['tf.nn.relu_29[0][0]']
#
#  batch_normalization_130 (B  (None, 14, 14, 1024)         4096      ['conv2d_130[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_9 (TF  (None, 14, 14, 1024)         0         ['tf.nn.relu_27[0][0]',
#  OpLambda)                                                           'batch_normalization_130[0][0
#                                                                     ]']
#
#  tf.nn.relu_30 (TFOpLambda)  (None, 14, 14, 1024)         0         ['tf.__operators__.add_9[0][0]
#                                                                     ']
#
#  conv2d_131 (Conv2D)         (None, 14, 14, 256)          262144    ['tf.nn.relu_30[0][0]']
#
#  batch_normalization_131 (B  (None, 14, 14, 256)          1024      ['conv2d_131[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_31 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_131[0][0
#                                                                     ]']
#
#  conv2d_132 (Conv2D)         (None, 14, 14, 256)          589824    ['tf.nn.relu_31[0][0]']
#
#  batch_normalization_132 (B  (None, 14, 14, 256)          1024      ['conv2d_132[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_32 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_132[0][0
#                                                                     ]']
#
#  conv2d_133 (Conv2D)         (None, 14, 14, 1024)         262144    ['tf.nn.relu_32[0][0]']
#
#  batch_normalization_133 (B  (None, 14, 14, 1024)         4096      ['conv2d_133[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_10 (T  (None, 14, 14, 1024)         0         ['tf.nn.relu_30[0][0]',
#  FOpLambda)                                                          'batch_normalization_133[0][0
#                                                                     ]']
#
#  tf.nn.relu_33 (TFOpLambda)  (None, 14, 14, 1024)         0         ['tf.__operators__.add_10[0][0
#                                                                     ]']
#
#  conv2d_134 (Conv2D)         (None, 14, 14, 256)          262144    ['tf.nn.relu_33[0][0]']
#
#  batch_normalization_134 (B  (None, 14, 14, 256)          1024      ['conv2d_134[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_34 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_134[0][0
#                                                                     ]']
#
#  conv2d_135 (Conv2D)         (None, 14, 14, 256)          589824    ['tf.nn.relu_34[0][0]']
#
#  batch_normalization_135 (B  (None, 14, 14, 256)          1024      ['conv2d_135[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_35 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_136 (Conv2D)         (None, 14, 14, 1024)         262144    ['tf.nn.relu_35[0][0]']
#
#  batch_normalization_136 (B  (None, 14, 14, 1024)         4096      ['conv2d_136[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_11 (T  (None, 14, 14, 1024)         0         ['tf.nn.relu_33[0][0]',
#  FOpLambda)                                                          'batch_normalization_136[0][0
#                                                                     ]']
#
#  tf.nn.relu_36 (TFOpLambda)  (None, 14, 14, 1024)         0         ['tf.__operators__.add_11[0][0
#                                                                     ]']
#
#  conv2d_137 (Conv2D)         (None, 14, 14, 256)          262144    ['tf.nn.relu_36[0][0]']
#
#  batch_normalization_137 (B  (None, 14, 14, 256)          1024      ['conv2d_137[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_37 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_137[0][0
#                                                                     ]']
#
#  conv2d_138 (Conv2D)         (None, 14, 14, 256)          589824    ['tf.nn.relu_37[0][0]']
#
#  batch_normalization_138 (B  (None, 14, 14, 256)          1024      ['conv2d_138[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_38 (TFOpLambda)  (None, 14, 14, 256)          0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  conv2d_139 (Conv2D)         (None, 14, 14, 1024)         262144    ['tf.nn.relu_38[0][0]']
#
#  batch_normalization_139 (B  (None, 14, 14, 1024)         4096      ['conv2d_139[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_12 (T  (None, 14, 14, 1024)         0         ['tf.nn.relu_36[0][0]',
#  FOpLambda)                                                          'batch_normalization_139[0][0
#                                                                     ]']
#
#  tf.nn.relu_39 (TFOpLambda)  (None, 14, 14, 1024)         0         ['tf.__operators__.add_12[0][0
#                                                                     ]']
#
#  conv2d_141 (Conv2D)         (None, 14, 14, 512)          524288    ['tf.nn.relu_39[0][0]']
#
#  batch_normalization_141 (B  (None, 14, 14, 512)          2048      ['conv2d_141[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_40 (TFOpLambda)  (None, 14, 14, 512)          0         ['batch_normalization_141[0][0
#                                                                     ]']
#
#  conv2d_142 (Conv2D)         (None, 7, 7, 512)            2359296   ['tf.nn.relu_40[0][0]']
#
#  batch_normalization_142 (B  (None, 7, 7, 512)            2048      ['conv2d_142[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_41 (TFOpLambda)  (None, 7, 7, 512)            0         ['batch_normalization_142[0][0
#                                                                     ]']
#
#  conv2d_140 (Conv2D)         (None, 7, 7, 2048)           2097152   ['tf.nn.relu_39[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 7, 7, 2048)           1048576   ['tf.nn.relu_41[0][0]']
#
#  batch_normalization_140 (B  (None, 7, 7, 2048)           8192      ['conv2d_140[0][0]']
#  atchNormalization)
#
#  batch_normalization_143 (B  (None, 7, 7, 2048)           8192      ['conv2d_143[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_13 (T  (None, 7, 7, 2048)           0         ['batch_normalization_140[0][0
#  FOpLambda)                                                         ]',
#                                                                      'batch_normalization_143[0][0
#                                                                     ]']
#
#  tf.nn.relu_42 (TFOpLambda)  (None, 7, 7, 2048)           0         ['tf.__operators__.add_13[0][0
#                                                                     ]']
#
#  conv2d_144 (Conv2D)         (None, 7, 7, 512)            1048576   ['tf.nn.relu_42[0][0]']
#
#  batch_normalization_144 (B  (None, 7, 7, 512)            2048      ['conv2d_144[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_43 (TFOpLambda)  (None, 7, 7, 512)            0         ['batch_normalization_144[0][0
#                                                                     ]']
#
#  conv2d_145 (Conv2D)         (None, 7, 7, 512)            2359296   ['tf.nn.relu_43[0][0]']
#
#  batch_normalization_145 (B  (None, 7, 7, 512)            2048      ['conv2d_145[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_44 (TFOpLambda)  (None, 7, 7, 512)            0         ['batch_normalization_145[0][0
#                                                                     ]']
#
#  conv2d_146 (Conv2D)         (None, 7, 7, 2048)           1048576   ['tf.nn.relu_44[0][0]']
#
#  batch_normalization_146 (B  (None, 7, 7, 2048)           8192      ['conv2d_146[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_14 (T  (None, 7, 7, 2048)           0         ['tf.nn.relu_42[0][0]',
#  FOpLambda)                                                          'batch_normalization_146[0][0
#                                                                     ]']
#
#  tf.nn.relu_45 (TFOpLambda)  (None, 7, 7, 2048)           0         ['tf.__operators__.add_14[0][0
#                                                                     ]']
#
#  conv2d_147 (Conv2D)         (None, 7, 7, 512)            1048576   ['tf.nn.relu_45[0][0]']
#
#  batch_normalization_147 (B  (None, 7, 7, 512)            2048      ['conv2d_147[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_46 (TFOpLambda)  (None, 7, 7, 512)            0         ['batch_normalization_147[0][0
#                                                                     ]']
#
#  conv2d_148 (Conv2D)         (None, 7, 7, 512)            2359296   ['tf.nn.relu_46[0][0]']
#
#  batch_normalization_148 (B  (None, 7, 7, 512)            2048      ['conv2d_148[0][0]']
#  atchNormalization)
#
#  tf.nn.relu_47 (TFOpLambda)  (None, 7, 7, 512)            0         ['batch_normalization_148[0][0
#                                                                     ]']
#
#  conv2d_149 (Conv2D)         (None, 7, 7, 2048)           1048576   ['tf.nn.relu_47[0][0]']
#
#  batch_normalization_149 (B  (None, 7, 7, 2048)           8192      ['conv2d_149[0][0]']
#  atchNormalization)
#
#  tf.__operators__.add_15 (T  (None, 7, 7, 2048)           0         ['tf.nn.relu_45[0][0]',
#  FOpLambda)                                                          'batch_normalization_149[0][0
#                                                                     ]']
#
#  tf.nn.relu_48 (TFOpLambda)  (None, 7, 7, 2048)           0         ['tf.__operators__.add_15[0][0
#                                                                     ]']
#
#  global_average_pooling2d_1  (None, 2048)                 0         ['tf.nn.relu_48[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_1 (Dense)             (None, 1000)                 2049000   ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 25610152 (97.69 MB)
# Trainable params: 25557032 (97.49 MB)
# Non-trainable params: 53120 (207.50 KB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## Reference
#
# - [ResNet Implementation using TensorFlow-2.0](https://github.com/calmiLovesAI/TensorFlow2.0_ResNet)
# - [PyTorch ResNet](https://github.com/pytorch/vision/blob/main/torchvision/models/resnet.py)
